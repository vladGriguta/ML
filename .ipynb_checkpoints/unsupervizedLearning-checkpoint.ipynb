# %% [markdown]
# # Unsupervized Learning
# ### Description
# In this notebook I plan to go through some theory aspects of unsupervized learning models. The applications will be focussed on clustering, anomaly detection and density estimation

# %% [markdown]
# 'If intelligence was the cake, unsupervized learning would be the cake, supervized learning would be the icing on the cake and reinforcement learning would be the cherry on the cake.'
# In other words, there is still a great potential for AI to improve our lifes by leveraging unsupervized learning.
#
# Definitions:
# Unsupervized learning:
#     Training a model on unlabelled data with the purpose of revealing the intrinsic paterns.
# Clustering:
#     Group similar instances together into clusters
# Anomaly Detection:
#     Learn what 'normal' data looks like and use it to detect abnormal instances.
# Density Estimation:
#     Estimate the PDF of the process that generated the data.

# %% [markdown]
# ## Clustering
# Examples:
# 1. Customer Segmentation
# 2. Dimensionality Reduction
# 3. Anomaly Detection
# 4. Semi-supervized learning (expand the labeling scheme to unlabeled data)
# 5. Image segmentation ('simplify' image by reducing the degrees of freedom of each pixel)
# 6. Search engines (provide samples from the same cluster)

# %% [markdown]
# # Exercises

# %% [markdown]
# ### 1. How would you define clustering? Can you name a few clustering algorithms?
# Clustering is type of unsupervized learning models that aims at grouping together instances in the training set based upon a certain average distance metric between each pair of instances.

# %% [markdown]
# ### 2. What are some of the main applications of clustering?
#  - customer segmentation
#  - anomaly detection
#  - semi-supervized learning
#  - search engines

# %% [markdown]
# ### 3. Describe two techniques to select the number of clusters in K-Means.
#  - elbow method: plot inertia (mean squared error between each instance and its centroid, available via kmeans.inertia_) versus the number of clusters and choose the point of largest inflexion
#  - plot silhouette score ((b-a)/max(a,b), a mean intercluster distance, b mean nearest cluster distance) versus number of clusters
#  - plot silhouette score of each instance versus number of clusters and compare against aggregate silhouette coefficient

# %% [markdown]
# ### 4. What is label propagation? Why would you implement it and how?
# Label propagation is the task of extending (propagating) the labeling scheme of the labeled data to the unlabeled data. This technique is applied in the context of semi-supervized learning, when the cost of labeling new instances of data is significant enough to make it efficien for ML engineers to automate the work.
# A labeling propagation mechanism involves using a clustering model to group together instances both labeled and unlabeled. By assuming that the labeled instances in a group give a fair representation of the whole instances in the group, one can assign those labels to the unlabeled data.
# One has to be wary of labeling evenly distributed data from the training set before applying the clustering method.

# %% [markdown]
# ### 5. Can you name two clustering algorithms that scale well to large datasets? And two that look for regions of high density?
#  - Mini Batch K-Means;
#  - DBSCAN, Gaussian Mixtures

# %% [markdown]
# ### 6. Can you think of a use case where active learning would be useful? How would you implement it?
# Active learning is the process in which human experts interact 'actively' with the training models to reinforce their learning. A typical use case for such an approach is when labelling the data is relatively expensive. In that case, human experts could be used to confirm the results of a clustering algorithm that would group data together based on labels. If results are confirmed, then the labeling can be extended to previously unlabeled data that are grouped together with data which was assigned the same label.

# %% [markdown]
# ### 7. What is the difference between anomaly detection and novelty detection?
# In anomaly detection the training dataset contains anomalous instances that needs to be identified. In novelty detection, all instances in the training set are 'normal' and the target is to learn the pattern in the training set and decide if new instances are of the same kind.

# %% [markdown]
# ### 8. What is a gaussian mixture? What tasks can you use it for?
# A gaussian mixture model is one which assumes that the training data was generated via a mixture of gaussian distributions with (potentially) varying centroids, means and standard deviations. The clustering objective is to estimate the distributions that sampled the training set.
# This class of versatile models can be used on various tasks, including clustering and anomaly detection.

# %% [markdown]
# ### 9. Can you name two techniques to find the right number of clusters when using a gaussian mixture model?
#  - aic / bic criteria
#  - bayesian inference

# %% [markdown]
# ### 10. Olivetti faces dataset

# %%
import numpy as np, pandas as pd, matplotlib.pyplot as plt

# %%
from sklearn.datasets import fetch_olivetti_faces
olivetti = fetch_olivetti_faces()

# %%
print(olivetti.DESCR)
# Out:
# .. _olivetti_faces_dataset:
#
# The Olivetti faces dataset
# --------------------------
#
# `This dataset contains a set of face images`_ taken between April 1992 and
# April 1994 at AT&T Laboratories Cambridge. The
# :func:`sklearn.datasets.fetch_olivetti_faces` function is the data
# fetching / caching function that downloads the data
# archive from AT&T.
#
# .. _This dataset contains a set of face images: http://www.cl.cam.ac.uk/research/dtg/attarchive/facedatabase.html
#
# As described on the original website:
#
#     There are ten different images of each of 40 distinct subjects. For some
#     subjects, the images were taken at different times, varying the lighting,
#     facial expressions (open / closed eyes, smiling / not smiling) and facial
#     details (glasses / no glasses). All the images were taken against a dark
#     homogeneous background with the subjects in an upright, frontal position
#     (with tolerance for some side movement).
#
# ...

# %%
print('data shape {}'.format(olivetti.data.shape))
print('images shape {}'.format(olivetti.images.shape))
print('target shape {}'.format(olivetti.target.shape))
# Out:
# data shape (400, 4096)
# images shape (400, 64, 64)
# target shape (400,)

# %%
# use stratified sampling to split the data in train / test / validation
from sklearn.model_selection import StratifiedShuffleSplit


split = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=8)

train_valid_idx, test_idx = next(split.split(olivetti.data, olivetti.target))

X_train_valid = olivetti.data[train_valid_idx]
y_train_valid = olivetti.target[train_valid_idx]
X_test = olivetti.data[test_idx]
y_test = olivetti.target[test_idx]


# once again stratified split for validation set

strat_split = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=8)
train_idx, valid_idx = next(strat_split.split(X_train_valid, y_train_valid))

X_train = X_train_valid[train_idx]
y_train = y_train_valid[train_idx]
X_valid = X_train_valid[valid_idx]
y_valid = y_train_valid[valid_idx]

# %%
# cluster images via k-means clustering with an optimum number of clusters
from sklearn.cluster import KMeans

k_range = range(10, 200, 10)
kmeans_list = []
for k in k_range:
    print("k={}".format(k))
    kmeans = KMeans(n_clusters=k, random_state=8).fit(X_train)
    kmeans_list.append(kmeans)
# Out:
# k=10
# k=20
# k=30
# k=40
# k=50
# k=60
# k=70
# k=80
# k=90
# k=100
# k=110
# k=120
# k=130
# k=140
# k=150
# k=160
# k=170
# k=180
# k=190

# %%
from sklearn.metrics import silhouette_score

silhouette_scores = [silhouette_score(X_train, kmeans.labels_) for kmeans in kmeans_list]
best_index = np.argmax(silhouette_scores)
best_k = k_range[best_index]
best_score = silhouette_scores[best_index]

plt.figure(figsize=(8, 3))
plt.plot(k_range, silhouette_scores, "bo-")
plt.xlabel("$k$", fontsize=14)
plt.ylabel("Silhouette score", fontsize=14)
plt.plot(best_k, best_score, "rs", label='{}'.format(best_k))
plt.legend()
plt.grid()

# %%
inertias = [kmeans.inertia_ for kmeans in kmeans_list]
best_inertia = inertias[best_index]

plt.figure(figsize=(8, 3.5))
plt.plot(k_range, inertias, "bo-")
plt.xlabel("$k$", fontsize=14)
plt.ylabel("Inertia", fontsize=14)
plt.plot(best_k, best_inertia, "rs",label='{}'.format(best_k))
plt.legend
plt.grid()

# %% [markdown]
# It is not necessarily clear that there is a best k from looking at the inertia - no obvious 'elbow'
# Exercise: Visualize the clustered faces

# %%
best_model = kmeans_list[best_index]

def plot_faces(faces, labels, n_cols=10):
    n_rows = (len(faces) - 1) // n_cols + 1
    plt.figure(figsize=(n_cols, n_rows * 1.1))
    for index, (face, label) in enumerate(zip(faces, labels)):
        plt.subplot(n_rows, n_cols, index + 1)
        plt.imshow(face.reshape(64, 64), cmap="gray")
        plt.axis("off")
        plt.title(label)
    plt.show()

for cluster_id in np.unique(best_model.labels_):
    print("Cluster", cluster_id)
    in_cluster = best_model.labels_==cluster_id
    faces = X_train[in_cluster].reshape(-1, 64, 64)
    labels = y_train[in_cluster]
    plot_faces(faces, labels)
# Out:
# Cluster 0
# Cluster 1
# Cluster 2
# Cluster 3
# Cluster 4
# Cluster 5
# Cluster 6
# Cluster 7
# Cluster 8
# Cluster 9
# Cluster 10
# Cluster 11
# Cluster 12
# Cluster 13
# Cluster 14
# Cluster 15
# Cluster 16
# Cluster 17
# Cluster 18
# Cluster 19
# Cluster 20
# Cluster 21
# Cluster 22
# Cluster 23
# Cluster 24
# Cluster 25
# Cluster 26
# Cluster 27
# Cluster 28
# Cluster 29
# Cluster 30
# Cluster 31
# Cluster 32
# Cluster 33
# Cluster 34
# Cluster 35
# Cluster 36
# Cluster 37
# Cluster 38
# Cluster 39
# Cluster 40
# Cluster 41
# Cluster 42
# Cluster 43
# Cluster 44
# Cluster 45
# Cluster 46
# Cluster 47
# Cluster 48
# Cluster 49
# Cluster 50
# Cluster 51
# Cluster 52
# Cluster 53
# Cluster 54
# Cluster 55
# Cluster 56
# Cluster 57
# Cluster 58
# Cluster 59
# Cluster 60
# Cluster 61
# Cluster 62
# Cluster 63
# Cluster 64
# Cluster 65
# Cluster 66
# Cluster 67
# Cluster 68
# Cluster 69
# Cluster 70
# Cluster 71
# Cluster 72
# Cluster 73
# Cluster 74
# Cluster 75
# Cluster 76
# ...

# %% [markdown]
# Clustering directly on the dataset with kmeans has proven to be too imprecise. Only in several of the 100 clusters did we get the same consistent face and a relatively hogh number of samples (say > 4).

# %% [markdown]
# ### 11. Continued Olivetti

# %%
# train a classifier to predict which person is represented in each picture and evaluate it on the training set
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier(n_estimators=100, random_state=8)
model.fit(X_train,y_train)

model.score(X_valid,y_valid)
# Out:
# 0.953125

# %%
# next, use kmeans as a dimensionality reduction method and train the classifier on the reduced set.

X_train_reduced = best_model.transform(X_train)
X_valid_reduced = best_model.transform(X_valid)

clf = RandomForestClassifier(n_estimators=100, random_state=8)
clf.fit(X_train_reduced, y_train)
    
clf.score(X_valid_reduced, y_valid)
# Out:
# 0.84375

# %%
# the accuracy of the classifier dropped. this confirms that the optimum of 100 clusters found for the kmeans
# via the silhouette score is not a global optimum
# search for the number of  clusters that allows the classifier to reach the optimum performance

from sklearn.pipeline import Pipeline

for n_clusters in k_range:
    pipeline = Pipeline([
        ("kmeans", KMeans(n_clusters=n_clusters, random_state=n_clusters)),
        ("forest_clf", RandomForestClassifier(n_estimators=100, random_state=8))
    ])
    pipeline.fit(X_train, y_train)
    print(n_clusters, pipeline.score(X_valid, y_valid))
# Out:
# 10 0.59375
# 20 0.6875
# 30 0.71875
# 40 0.71875
# 50 0.796875
# 60 0.84375
# 70 0.765625
# 80 0.828125
# 90 0.796875
# 100 0.8125
# 110 0.8125
# 120 0.796875
# 130 0.8125
# 140 0.84375
# 150 0.890625
# 160 0.84375
# 170 0.890625
# 180 0.890625
# 190 0.84375

# %%
# append the features from the dataset to the original features
for n_clusters in k_range:
    kmeans = KMeans(n_clusters=n_clusters, random_state=8).fit(X_train)
    X_train_extended = np.c_[X_train,kmeans.transform(X_train)]
    X_valid_extended = np.c_[X_valid,kmeans.transform(X_valid)]
    
    model.fit(X_train_extended, y_train)
    
    print(n_clusters, model.score(X_valid_extended, y_valid))
# Out:
# 10 0.984375
# 20 0.9375
# 30 0.96875
# 40 0.96875
# 50 0.9375
# 60 0.953125
# 70 0.96875
# 80 0.953125
# 90 0.984375
# 100 0.9375
# 110 0.984375
# 120 0.984375
# 130 0.953125
# 140 0.953125
# 150 0.90625
# 160 0.984375
# 170 0.96875
# 180 0.953125
# 190 0.96875

# %% [markdown]
# There is no consistent trend in the way that the score of the classifier varies with the number of clusters.
# Without clustering, the RF classifier scores 95%, whereas after addind the features computed from the clusters the classifier scores sometimes above and sometimes bellow this benchmark.

# %% [markdown]
# ### 12. Olivetti continued - Gaussian mixture

# %%
# apply pca and preserve 99% of the variance
from sklearn.decomposition import PCA

pca = PCA(0.99)
X_train_pca = pca.fit_transform(X_train)
X_valid_pca = pca.transform(X_valid)
X_test_pca = pca.transform(X_test)

print('initial size = {}'.format(olivetti.data.shape[1]))
print('new size = {}'.format(pca.n_components_))
# Out:
# initial size = 4096
# new size = 185

# %%
# train a GMM
from sklearn.mixture import GaussianMixture

gm = GaussianMixture(n_components=40, random_state=8)
y_pred = gm.fit_predict(X_train_pca)

# %%
# use the GMM to generate new faces
n_gen_faces = 20
gen_faces_reduced, y_gen_faces = gm.sample(n_samples=n_gen_faces)
gen_faces = pca.inverse_transform(gen_faces_reduced)

plot_faces(gen_faces,y_gen_faces)

# %%
# rotate, flip, darken images to see if the model can detect anomalies
n_rotated = 5
rotated = np.transpose(X_train[:n_rotated].reshape(-1, 64, 64), axes=[0, 2, 1])
rotated = rotated.reshape(-1, 64*64)
y_rotated = y_train[:n_rotated]

n_flipped = 5
flipped = X_train[:n_flipped].reshape(-1, 64, 64)[:, ::-1]
flipped = flipped.reshape(-1, 64*64)
y_flipped = y_train[:n_flipped]

n_darkened = 5
darkened = X_train[:n_darkened].copy()
darkened[:, 1:-1] *= 0.3
darkened = darkened.reshape(-1, 64*64)
y_darkened = y_train[:n_darkened]

X_bad_faces = np.r_[rotated, flipped, darkened]
y_bad = np.concatenate([y_rotated, y_flipped, y_darkened])

plot_faces(X_bad_faces, y_bad)

# %%
X_bad_faces_pca = pca.transform(X_bad_faces)
print('scores of modified images = {}'.format(gm.score_samples(X_bad_faces_pca)))
print('\n\n\nscores of initial images = {}'.format(gm.score_samples(X_train_pca[:5])))
# Out:
# scores of modified images = [-4.09629265e+07 -3.56500298e+07 -2.56303385e+07 -3.80076719e+07
#  -4.04369336e+07 -2.69167954e+07 -2.88050529e+07 -3.65130416e+07
#  -5.34991437e+07 -3.25927549e+07 -1.19001796e+08 -8.70848822e+07
#  -1.05090581e+08 -1.04458120e+08 -1.18377767e+08]
#
#
#
# scores of initial images = [1056.59076802 1033.26825402 1063.64020847 1062.37870237 1078.82608102]

# %% [markdown]
# All modifications to the images made them outliers. This is indicative of the fact that gaussian mixtures cannot predict well on new images. Let's try:

# %%
print('scores of modified images = {}'.format(gm.score_samples(X_valid_pca[:5])))
# Out:
# scores of modified images = [ -2176748.76968885 -10317280.7070135  -14108356.01060736
#   -4508416.81705217  -9401322.28715715]

# %% [markdown]
# ### 13. Olivetti continued - anomaly detection

# %%
# function to compute reconstruction error
from sklearn.metrics import mean_squared_error
def reconstruction_errors(X,pca=pca):
    X_pca = pca.transform(X)
    X_reconstructed = pca.inverse_transform(X_pca)
    mse = mean_squared_error(X_reconstructed, X)
    return mse

# %%
reconstruction_errors(X_train)
# Out:
# 0.00019146441

# %%
reconstruction_errors(X_bad_faces)
# Out:
# 0.005350552

# %%
plot_faces(X_bad_faces, y_gen_faces)

# %%
X_bad_faces_reconstructed = pca.inverse_transform(X_bad_faces_pca)
plot_faces(X_bad_faces_reconstructed, y_gen_faces)

# %%
# the reason why the reconstruction error of the new bad samples is so high is that the pca tries to reconstruct
# the faces at exactly the same positions (e.g. upside, straight, same luminosity)
